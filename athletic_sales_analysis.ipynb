# %%
# Import Libraries and Dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
data_file_path = Path("Resources/athletic_sales_2020.csv")
data_file_path_2= Path("Resources/athletic_sales_2021.csv")


data_file_2020 =pd.read_csv(data_file_path)
data_file_2021=pd.read_csv(data_file_path_2)

# %%
# Display the 2020 sales DataFrame
data_file_2020
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
data_file_2021
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
print(data_file_2020.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          1297 non-null   object
#  1   retailer_id       1297 non-null   int64
#  2   invoice_date      1297 non-null   object
#  3   region            1297 non-null   object
#  4   state             1297 non-null   object
#  5   city              1297 non-null   object
#  6   product           1297 non-null   object
#  7   price_per_unit    1297 non-null   int64
#  8   units_sold        1297 non-null   int64
#  9   total_sales       1297 non-null   int64
#  10  operating_profit  1297 non-null   float64
#  11  sales_method      1297 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 121.7+ KB
# None

# %%
# Check the 2021 sales data types.
print(data_file_2021.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8346 entries, 0 to 8345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          8346 non-null   object
#  1   retailer_id       8346 non-null   int64
#  2   invoice_date      8346 non-null   object
#  3   region            8346 non-null   object
#  4   state             8346 non-null   object
#  5   city              8346 non-null   object
#  6   product           8346 non-null   object
#  7   price_per_unit    8346 non-null   int64
#  8   units_sold        8346 non-null   int64
#  9   total_sales       8346 non-null   int64
#  10  operating_profit  8346 non-null   float64
#  11  sales_method      8346 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 782.6+ KB
# None

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
joined_data_20_21 = pd.concat([ data_file_2021 , data_file_2021 ], axis = "rows" , join="inner" )
joined_data_20_21
reset_index_20_21 = joined_data_20_21.reset_index(drop=True)
reset_index_20_21
# Out:
#           retailer  retailer_id invoice_date     region         state  \
# 0        West Gear      1128299       1/1/21       West    California
# 1        West Gear      1128299       1/1/21       West    California
# 2           Kohl's      1189833       1/1/21    Midwest       Montana
# 3           Kohl's      1189833       1/1/21    Midwest       Montana
# 4        West Gear      1128299       1/1/21       West    California
# ...            ...          ...          ...        ...           ...
# 16687  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 16688  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 16689       Amazon      1185732     12/31/21  Northeast         Maine
# 16690       Amazon      1185732     12/31/21  Northeast         Maine
# 16691  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                 city                  product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
null_values = reset_index_20_21.isnull().sum()
null_values
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
columns_name = reset_index_20_21.columns
print(columns_name)
# Out:
# Index(['retailer', 'retailer_id', 'invoice_date', 'region', 'state', 'city',
#        'product', 'price_per_unit', 'units_sold', 'total_sales',
#        'operating_profit', 'sales_method'],
#       dtype='object')

# %%
reset_index_20_21['retailer'].value_counts
reset_index_20_21
# Out:
#           retailer  retailer_id invoice_date     region         state  \
# 0        West Gear      1128299       1/1/21       West    California
# 1        West Gear      1128299       1/1/21       West    California
# 2           Kohl's      1189833       1/1/21    Midwest       Montana
# 3           Kohl's      1189833       1/1/21    Midwest       Montana
# 4        West Gear      1128299       1/1/21       West    California
# ...            ...          ...          ...        ...           ...
# 16687  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 16688  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 16689       Amazon      1185732     12/31/21  Northeast         Maine
# 16690       Amazon      1185732     12/31/21  Northeast         Maine
# 16691  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                 city                  product  price_per_unit  units_sold  \
# ...

# %%
columns_to_check = ['retailer', 'retailer_id', 'invoice_date', 'region', 'state', 'city',
       'product', 'price_per_unit', 'units_sold', 'total_sales',
       'operating_profit', 'sales_method'] 
print(reset_index_20_21[columns_to_check].apply(lambda x: x.unique()))
# Out:
# retailer            [West Gear, Kohl's, Foot Locker, Sports Direct...
# retailer_id                      [1128299, 1189833, 1185732, 1197831]
# invoice_date        [1/1/21, 1/2/21, 1/3/21, 1/4/21, 1/5/21, 1/6/2...
# region                   [West, Midwest, South, Southeast, Northeast]
# state               [California, Montana, Iowa, Louisiana, South C...
# city                [San Francisco, Billings, Des Moines, New Orle...
# product             [Men's Athletic Footwear, Men's Apparel, Women...
# price_per_unit      [65, 51, 50, 47, 64, 45, 60, 46, 43, 20, 30, 5...
# units_sold          [750, 233, 275, 77, 225, 475, 218, 138, 250, 4...
# total_sales         [487500, 11883, 137500, 3619, 14400, 213750, 1...
# operating_profit    [121875.0, 3208.41, 82500.0, 2714.25, 5184.0, ...
# sales_method                               [Outlet, Online, In-store]
# dtype: object

# %%
unique_values_dict = {col: reset_index_20_21[col].unique() for col in columns_to_check}
print(unique_values_dict)
# Out:
# {'retailer': array(['West Gear', "Kohl's", 'Foot Locker', 'Sports Direct', 'Amazon',
#        'Walmart'], dtype=object), 'retailer_id': array([1128299, 1189833, 1185732, 1197831]), 'invoice_date': array(['1/1/21', '1/2/21', '1/3/21', '1/4/21', '1/5/21', '1/6/21',
#        '1/7/21', '1/8/21', '1/9/21', '1/10/21', '1/11/21', '1/12/21',
#        '1/13/21', '1/14/21', '1/15/21', '1/16/21', '1/17/21', '1/18/21',
#        '1/19/21', '1/20/21', '1/21/21', '1/22/21', '1/23/21', '1/24/21',
#        '1/25/21', '1/26/21', '1/27/21', '1/28/21', '1/29/21', '1/30/21',
#        '1/31/21', '2/1/21', '2/2/21', '2/3/21', '2/4/21', '2/5/21',
#        '2/6/21', '2/7/21', '2/8/21', '2/9/21', '2/10/21', '2/11/21',
#        '2/12/21', '2/13/21', '2/14/21', '2/15/21', '2/16/21', '2/17/21',
#        '2/18/21', '2/19/21', '2/20/21', '2/21/21', '2/22/21', '2/23/21',
#        '2/24/21', '2/25/21', '2/26/21', '2/27/21', '2/28/21', '3/1/21',
#        '3/2/21', '3/3/21', '3/4/21', '3/5/21', '3/6/21', '3/7/21',
# ...

# %%
# Check the data type of each column

print(reset_index_20_21.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16692 entries, 0 to 16691
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          16692 non-null  object
#  1   retailer_id       16692 non-null  int64
#  2   invoice_date      16692 non-null  object
#  3   region            16692 non-null  object
#  4   state             16692 non-null  object
#  5   city              16692 non-null  object
#  6   product           16692 non-null  object
#  7   price_per_unit    16692 non-null  int64
#  8   units_sold        16692 non-null  int64
#  9   total_sales       16692 non-null  int64
#  10  operating_profit  16692 non-null  float64
#  11  sales_method      16692 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.5+ MB
# None

# %%
# Convert the "invoice_date" to a datetime datatype
reset_index_20_21['invoice_date'] = pd.to_datetime(reset_index_20_21['invoice_date'])
reset_index_20_21
# Out:
# /var/folders/qx/wdt486c517n4vrrtq8dnsww40000gn/T/ipykernel_25714/2191814924.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   reset_index_20_21['invoice_date'] = pd.to_datetime(reset_index_20_21['invoice_date'])
#           retailer  retailer_id invoice_date     region         state  \
# 0        West Gear      1128299   2021-01-01       West    California
# 1        West Gear      1128299   2021-01-01       West    California
# 2           Kohl's      1189833   2021-01-01    Midwest       Montana
# 3           Kohl's      1189833   2021-01-01    Midwest       Montana
# 4        West Gear      1128299   2021-01-01       West    California
# ...            ...          ...          ...        ...           ...
# 16687  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.
print(reset_index_20_21.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16692 entries, 0 to 16691
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          16692 non-null  object
#  1   retailer_id       16692 non-null  int64
#  2   invoice_date      16692 non-null  datetime64[ns]
#  3   region            16692 non-null  object
#  4   state             16692 non-null  object
#  5   city              16692 non-null  object
#  6   product           16692 non-null  object
#  7   price_per_unit    16692 non-null  int64
#  8   units_sold        16692 non-null  int64
#  9   total_sales       16692 non-null  int64
#  10  operating_profit  16692 non-null  float64
#  11  sales_method      16692 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
products_sold = reset_index_20_21[['region','state','city','units_sold']]
products_sold 
products_sum = products_sold.groupby(['region','state','city']).sum()
products_sum
products_sum = products_sum.rename(columns={'units_sold':'Total_products_sold'}, level=0)
products_sum.head()
# Out:
#                                Total_products_sold
# region  state    city
# Midwest Illinois Chicago                     50814
#         Indiana  Indianapolis                52664
#         Iowa     Des Moines                  46892
#         Kansas   Wichita                     58926
#         Michigan Detroit                    100190

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_table = pd.pivot_table(reset_index_20_21, values='units_sold', 
                             index=['region', 'state', 'city'], 
                             aggfunc='sum')
# Rename the "units_sold" column to "Total_Products_Sold"

pivot_table.rename(columns={'units_sold':'Total_Products_Sold'},inplace=True)
# Show the top 5 results.
pivot_table.head()
# Out:
#                                Total_Products_Sold
# region  state    city
# Midwest Illinois Chicago                     50814
#         Indiana  Indianapolis                52664
#         Iowa     Des Moines                  46892
#         Kansas   Wichita                     58926
#         Michigan Detroit                    100190

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
total_sale = reset_index_20_21[['region','state','city','total_sales']]
total_sale= total_sale.rename(columns={'total_sales':'Total Sales'},level=0)
total_sale
total_sale_gp = total_sale.groupby(['region','state','city'])

# Show the top 5 results.
total_sale_gp.count().head(5)
# Out:
#                                Total Sales
# region  state    city
# Midwest Illinois Chicago               288
#         Indiana  Indianapolis          288
#         Iowa     Des Moines            288
#         Kansas   Wichita               288
#         Michigan Detroit               288

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
totale_sale_rsc = pd.pivot_table(reset_index_20_21,
                                 index=['region','state','city'],
                                 values='total_sales',
                                 aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"

totals = totale_sale_rsc.rename(columns={"total_sales": "Total Sales"})


# Show the top 5 results.
totals.head()
# Out:
#                                Total Sales
# region  state    city
# Midwest Illinois Chicago          19594976
#         Indiana  Indianapolis     17672396
#         Iowa     Des Moines       14848022
#         Kansas   Wichita          19945728
#         Michigan Detroit          37250866

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
total_sale_ret = reset_index_20_21[['retailer','region','state','city','total_sales']]
total_sale_ret= total_sale_ret.rename(columns={'total_sales':'Total Sales'},level=0)
total_sale_ret
total_sale_ret_gp = total_sale_ret.groupby(['retailer','region','state','city'])

# Show the top 5 results.

total_sale_ret_gp.count().head()
# Out:
#                                              Total Sales
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus            272
#          Northeast Maine         Portland            272
#                    Massachusetts Boston              132
#                    New Hampshire Manchester          270
#                    Vermont       Burlington          408

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
totale_sale_rsc_ret = pd.pivot_table(reset_index_20_21,
                                 index=['retailer','region','state','city'],
                                 values='total_sales',
                                 aggfunc='count'
                                 )

# Optional: Rename the "total_sales" column to "Total Sales"
totals_ret = totale_sale_rsc_ret.rename(columns={"total_sales": "Total Sales"})

# Show the top 5 results.
totals_ret.head()
# Out:
#                                              Total Sales
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus            272
#          Northeast Maine         Portland            272
#                    Massachusetts Boston              132
#                    New Hampshire Manchester          270
#                    Vermont       Burlington          408

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_athletic_footwear_sales = reset_index_20_21[reset_index_20_21['product'] == "Women's Athletic Footwear"]
womens_athletic_footwear_sales
# Out:
#           retailer  retailer_id invoice_date     region         state  \
# 13       West Gear      1128299   2021-01-03       West    California
# 15       West Gear      1128299   2021-01-03       West    California
# 16       West Gear      1185732   2021-01-03    Midwest          Iowa
# 20       West Gear      1185732   2021-01-03    Midwest          Iowa
# 24       West Gear      1128299   2021-01-03       West    California
# ...            ...          ...          ...        ...           ...
# 16682  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 16683  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 16684       Amazon      1185732   2021-12-30  Northeast         Maine
# 16685       Amazon      1185732   2021-12-30  Northeast         Maine
# 16686  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
#
#                 city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
total_sale_women = womens_athletic_footwear_sales.groupby(['retailer','region','state','city'])[['units_sold']].count()
total_sale_women= total_sale_women.rename(columns={'units_sold':'Womens_Footwear_Units_Sold'},level=0)
total_sale_women
# Show the top 5 results.
total_sale_women.head(5)
# Out:
#                                              Womens_Footwear_Units_Sold
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus                            44
#          Northeast Maine         Portland                            44
#                    Massachusetts Boston                              18
#                    New Hampshire Manchester                          48
#                    Vermont       Burlington                          72

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.

womens_sales_pivot = pd.pivot_table(womens_athletic_footwear_sales,
                                 index=['retailer','region','state','city'],
                                 values='total_sales',
                                 aggfunc='count'
                                 )

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

womens_sales_pivot_ren= womens_sales_pivot.rename(columns={"total_sales": "Womens_Footwear_Units_Sold"})
# Show the top 5 results.
womens_sales_pivot_ren.head()
# Out:
#                                              Womens_Footwear_Units_Sold
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus                            44
#          Northeast Maine         Portland                            44
#                    Massachusetts Boston                              18
#                    New Hampshire Manchester                          48
#                    Vermont       Burlington                          72

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
new_pivot_invoicedate = pd.pivot_table(womens_athletic_footwear_sales,
                                      index='invoice_date',
                                      value='total_sales',
                                      aggfunc='sum'
                                      )


# Optional: Rename the "total_sales" column to "Total Sales"


new_pivot_invoicedate.rename(columns={'total_sales': 'Total Sales'}, inplace=True)
# Show the table.
print(new_pivot_invoicedate.head(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[367], line 2
#       1 # Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
# ----> 2 new_pivot_invoicedate = pd.pivot_table(womens_athletic_footwear_sales,
#       3                                       index='invoice_date',
#       4                                       value='total_sales',
#       5                                       aggfunc='sum'
#       6                                       )
#       9 # Optional: Rename the "total_sales" column to "Total Sales"
#      12 new_pivot_invoicedate.rename(columns={'total_sales': 'Total Sales'}, inplace=True)
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_sales = new_pivot_invoicedate.resample('D').sum()

# Sort the resampled pivot table in descending order on "Total Sales".
daily_sales_sorted = daily_sales.sort_values(by='Total Sales', ascending=False)

# Show the resampled and sorted pivot table
print(daily_sales_sorted.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[368], line 2
#       1 # Resample the pivot table into daily bins, and get the total sales for each day.
# ----> 2 daily_sales = new_pivot_invoicedate.resample('D').sum()
#       4 # Sort the resampled pivot table in descending order on "Total Sales".
#       5 daily_sales_sorted = daily_sales.sort_values(by='Total Sales', ascending=False)
#
# NameError: name 'new_pivot_invoicedate' is not defined

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_sales = new_pivot_invoicedate.resample('W').sum()

# Sort the resampled pivot table in descending order on "Total Sales".
weekly_sales_sorted = weekly_sales.sort_values(by='Total Sales', ascending=False)
print(weekly_sales_sorted.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[369], line 2
#       1 # Resample the pivot table into weekly bins, and get the total sales for each week.
# ----> 2 weekly_sales = new_pivot_invoicedate.resample('W').sum()
#       4 # Sort the resampled pivot table in descending order on "Total Sales".
#       5 weekly_sales_sorted = weekly_sales.sort_values(by='Total Sales', ascending=False)
#
# NameError: name 'new_pivot_invoicedate' is not defined
